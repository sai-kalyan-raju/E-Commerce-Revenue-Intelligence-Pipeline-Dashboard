# %%
import pandas as pd
import numpy as np
import sqlite3

# %%
# Loading data
orders_df = pd.read_csv("D:\Data (D)\Kalyan\Project\E-Commerce Dashboard\List of Orders.csv")
details_df = pd.read_csv("D:\Data (D)\Kalyan\Project\E-Commerce Dashboard\Order Details.csv")
target_df = pd.read_csv("D:\Data (D)\Kalyan\Project\E-Commerce Dashboard\Sales target.csv")

# %%
orders_df.head(3)
# Out:
#   Order ID  Order Date CustomerName           State       City
# 0  B-25601  01-04-2018       Bharat         Gujarat  Ahmedabad
# 1  B-25602  01-04-2018        Pearl     Maharashtra       Pune
# 2  B-25603  03-04-2018        Jahan  Madhya Pradesh     Bhopal
